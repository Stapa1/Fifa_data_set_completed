# %%
import pandas as pd
import numpy as np

# %%
# url = 'https://github.com/Stapa1/Fifa_world_cup_data_set.git/Fifa World Cup Points Table.csv'
# df1 = pd.read_csv(url)
# # Dataset is now stored in a Pandas Dataframe
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10b948e6-f2e1-4a68-97e8-a6640aa34b17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10b948e6-f2e1-4a68-97e8-a6640aa34b17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Fifa.csv']))
# df2
print(df2)
# Dataset is now stored in a Pandas Dataframe
# Out:
#     Unnamed: 0            Teams  MP  W  D  L  GF  GA  +/-  Pts Group
# 0            0  Netherlands (Q)   3  2  1  0   5   1    4    7     A
# 1            1      Senegal (Q)   3  2  0  1   4   3    1    6     A
# 2            2          Ecuador   3  1  1  1   4   3    1    4     A
# 3            3            Qatar   3  0  0  3   1   7   -6    0     A
# 4            4      England (Q)   3  2  1  0   9   2    7    7     B
# 5            5          USA (Q)   3  1  2  0   2   1    1    5     B
# 6            6             Iran   3  1  0  2   4   7   -3    3     B
# 7            7            Wales   3  0  1  2   1   6   -5    1     B
# 8            8    Argentina (Q)   3  2  0  1   5   2    3    6     C
# 9            9       Poland (Q)   3  1  1  1   2   2    0    4     C
# 10          10           Mexico   3  1  1  1   2   3   -1    4     C
# 11          11     Saudi Arabia   3  0  1  2   3   4   -1    3     C
# 12          12       France (Q)   3  2  0  1   6   3    3    6     D
# ...

# %% [markdown]
# 1.Count
#
# In order to find out the number of records present in the data set, count()function can be used. The data frame name should be specified when using this function

# %%
df2.count()
# Out:
# Unnamed: 0    32
# Teams         32
# MP            32
# W             32
# D             32
# L             32
# GF            32
# GA            32
# +/-           32
# Pts           32
# Group         32
# dtype: int64

# %% [markdown]
# 2 maxnimum
#
#
# he max() function can be used to find out the maximum value in a column.

# %%
df2.max()
# Out:
# Unnamed: 0       31
# Teams         Wales
# MP                3
# W                 3
# D                 2
# L                 3
# GF                9
# GA               11
# +/-               7
# Pts               7
# Group             H
# dtype: object

# %% [markdown]
# 3 Minimum
#
#
# The minimum can be taken in the same way we have done with the max function

# %%
df2.min()
# Out:
# Unnamed: 0                0
# Teams         Argentina (Q)
# MP                        3
# W                         0
# D                         0
# L                         0
# GF                        1
# GA                        1
# +/-                      -8
# Pts                       0
# Group                     A
# dtype: object

# %% [markdown]
# 4  Mean
#
# The mean is the average value of a given set of values.

# %%
df2.mean()
# Out:
# <ipython-input-27-4a56ca50fe8e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.mean()
# Unnamed: 0    15.50000
# MP             3.00000
# W              1.18750
# D              0.65625
# L              1.18750
# GF             3.81250
# GA             3.65625
# +/-            0.03125
# Pts            4.00000
# dtype: float64

# %% [markdown]
# 5. Median
#
# Median is the middle value of a given data set.

# %%
df2.median()
# Out:
# <ipython-input-28-05e26ec02eba>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.median()
# Unnamed: 0    15.5
# MP             3.0
# W              1.0
# D              1.0
# L              1.0
# GF             4.0
# GA             3.0
# +/-            0.0
# Pts            4.0
# dtype: float64

# %% [markdown]
# 6   Mode
#
# The mode is the most repeated value of a given data set.

# %%
df2.mode()
# Out:
#     Unnamed: 0            Teams   MP    W    D    L   GF   GA  +/-  Pts Group
# 0            0    Argentina (Q)  3.0  1.0  1.0  1.0  4.0  3.0  0.0  4.0     A
# 1            1    Australia (Q)  NaN  NaN  NaN  NaN  NaN  NaN  1.0  NaN     B
# 2            2          Belgium  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     C
# 3            3       Brazil (Q)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     D
# 4            4         Cameroon  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     E
# 5            5           Canada  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     F
# 6            6       Costa Rica  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     G
# 7            7      Croatia (Q)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     H
# 8            8          Denmark  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 9            9          Ecuador  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 10          10      England (Q)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# ...

# %% [markdown]
# 7 Standard Deviation
#
# In the same way as the other functions are used, in order to find the Standard Deviation std()function can be used.

# %%
df2.std()
# Out:
# <ipython-input-30-cefa5b2080f7>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.std()
# Unnamed: 0    9.380832
# MP            0.000000
# W             0.780302
# D             0.601577
# L             0.780302
# GF            2.101267
# GA            2.470593
# +/-           3.277335
# Pts           2.047816
# dtype: float64

# %% [markdown]
# 8 info function
#
# The info() function can be used to get a summary of index and column data types, non-null values, and the memory usage

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     int64
#  1   Teams       32 non-null     object
#  2   MP          32 non-null     int64
#  3   W           32 non-null     int64
#  4   D           32 non-null     int64
#  5   L           32 non-null     int64
#  6   GF          32 non-null     int64
#  7   GA          32 non-null     int64
#  8   +/-         32 non-null     int64
#  9   Pts         32 non-null     int64
#  10  Group       32 non-null     object
# dtypes: int64(9), object(2)
# memory usage: 2.9+ KB

# %% [markdown]
# 9 Describe function
#
# Rather than column-wise obtaining the mode, median, std, etc. using the relevant functions, describe() function can be used. It gives the summarized version of the calculated mode, median, std, max, min, percentile values

# %%
# import statistics
# print(statistics.mean(df2))
# def calculate_mean(n):
#       s=sum(n)
#       N=len(n)
#     # Calculate the mean
#       mean=s/N    
#       return mean

df2.describe()
# Out:
#        Unnamed: 0    MP          W          D          L         GF  \
# count   32.000000  32.0  32.000000  32.000000  32.000000  32.000000
# mean    15.500000   3.0   1.187500   0.656250   1.187500   3.812500
# std      9.380832   0.0   0.780302   0.601577   0.780302   2.101267
# min      0.000000   3.0   0.000000   0.000000   0.000000   1.000000
# 25%      7.750000   3.0   1.000000   0.000000   1.000000   2.000000
# 50%     15.500000   3.0   1.000000   1.000000   1.000000   4.000000
# 75%     23.250000   3.0   2.000000   1.000000   2.000000   5.000000
# max     31.000000   3.0   3.000000   2.000000   3.000000   9.000000
#
#               GA        +/-        Pts
# count  32.000000  32.000000  32.000000
# mean    3.656250   0.031250   4.000000
# std     2.470593   3.277335   2.047816
# min     1.000000  -8.000000   0.000000
# 25%     2.000000  -2.000000   3.000000
# 50%     3.000000   0.000000   4.000000
# 75%     4.250000   2.000000   6.000000
# ...
